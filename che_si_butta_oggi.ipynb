# %%
# !pip install openai

# %%
# !pip install python-dotenv

# %%
import openai
import os

from dotenv import load_dotenv, find_dotenv
_ = load_dotenv(find_dotenv()) # read local .env file

openai.api_key  = os.getenv('OPENAI_API_KEY')

# %%
def get_completion(prompt, model="gpt-3.5-turbo"):
    messages = [{"role": "user", "content": prompt}]
    response = openai.ChatCompletion.create(
        model=model,
        messages=messages,
        temperature=0, # this is the degree of randomness of the model's output
    )
    return response.choices[0].message["content"]

# %%
calendar_may = """
				<!-- ko foreach: Mese().Giorni-->
				<div class="row row-calendar" data-bind="css: {'row-today' : moment().format('DD/MMM/YYYY') == moment(Data).format('DD/MMM/YYYY') }, attr: {id: 'scroll-today'}" id="scroll-today">
					<div class="col-1 align-self-center text-center">
						<p class="my-0"><span data-bind="text: Data ? moment(Data).format('D') : '', css: {'text-info': Festivo}" class="text-info">1</span></p>
					</div>
					<div class="col-3 align-self-center">
						<p class="my-0"><span data-bind="text: GiornoDellaSettimana, css: {'text-info': Festivo}, attr:{title: Festivo ? Festivita : ''}" class="text-info" title="Festa del lavoro">Lunedì</span></p>
					</div>
					<div class="col-8">
						<div class="row">
							<!-- ko foreach: Eventi --><!-- /ko -->
						</div>
					</div>
				</div>
				
				<div class="row row-calendar row-today" data-bind="css: {'row-today' : moment().format('DD/MMM/YYYY') == moment(Data).format('DD/MMM/YYYY') }, attr: {id: 'scroll-today'}" id="scroll-today">
					<div class="col-1 align-self-center text-center">
						<p class="my-0"><span data-bind="text: Data ? moment(Data).format('D') : '', css: {'text-info': Festivo}">2</span></p>
					</div>
					<div class="col-3 align-self-center">
						<p class="my-0"><span data-bind="text: GiornoDellaSettimana, css: {'text-info': Festivo}, attr:{title: Festivo ? Festivita : ''}" title="">Martedì</span></p>
					</div>
					<div class="col-8">
						<div class="row">
							<!-- ko foreach: Eventi -->
							<div class="col-2 align-self-center">
								<div class="calendar-box" data-bind="style: {'background-color': Colore ? '#' + Colore : '#BBBBBB' }, attr: {title: Testo}" title="Secco" style="background-color: rgb(131, 126, 133);"><p class="my-0">&nbsp;</p></div>
							</div>
							<div class="col-4 align-self-center">
								<p class="my-0"><strong data-bind="text: Testo">Secco</strong></p>
							</div>
							
							<div class="col-2 align-self-center">
								<div class="calendar-box" data-bind="style: {'background-color': Colore ? '#' + Colore : '#BBBBBB' }, attr: {title: Testo}" title="Umido" style="background-color: rgb(148, 73, 6);"><p class="my-0">&nbsp;</p></div>
							</div>
							<div class="col-4 align-self-center">
								<p class="my-0"><strong data-bind="text: Testo">Umido</strong></p>
							</div>
							<!-- /ko -->
						</div>
					</div>
				</div>
				
				<div class="row row-calendar" data-bind="css: {'row-today' : moment().format('DD/MMM/YYYY') == moment(Data).format('DD/MMM/YYYY') }, attr: {id: 'scroll-today'}" id="scroll-today">
					<div class="col-1 align-self-center text-center">
						<p class="my-0"><span data-bind="text: Data ? moment(Data).format('D') : '', css: {'text-info': Festivo}">3</span></p>
					</div>
					<div class="col-3 align-self-center">
						<p class="my-0"><span data-bind="text: GiornoDellaSettimana, css: {'text-info': Festivo}, attr:{title: Festivo ? Festivita : ''}" title="">Mercoledì</span></p>
					</div>
					<div class="col-8">
						<div class="row">
							<!-- ko foreach: Eventi --><!-- /ko -->
						</div>
					</div>
				</div>
				
				<div class="row row-calendar" data-bind="css: {'row-today' : moment().format('DD/MMM/YYYY') == moment(Data).format('DD/MMM/YYYY') }, attr: {id: 'scroll-today'}" id="scroll-today">
					<div class="col-1 align-self-center text-center">
						<p class="my-0"><span data-bind="text: Data ? moment(Data).format('D') : '', css: {'text-info': Festivo}">4</span></p>
					</div>
					<div class="col-3 align-self-center">
						<p class="my-0"><span data-bind="text: GiornoDellaSettimana, css: {'text-info': Festivo}, attr:{title: Festivo ? Festivita : ''}" title="">Giovedì</span></p>
					</div>
					<div class="col-8">
						<div class="row">
							<!-- ko foreach: Eventi --><!-- /ko -->
						</div>
					</div>
				</div>
				
				<div class="row row-calendar" data-bind="css: {'row-today' : moment().format('DD/MMM/YYYY') == moment(Data).format('DD/MMM/YYYY') }, attr: {id: 'scroll-today'}" id="scroll-today">
					<div class="col-1 align-self-center text-center">
						<p class="my-0"><span data-bind="text: Data ? moment(Data).format('D') : '', css: {'text-info': Festivo}">5</span></p>
					</div>
					<div class="col-3 align-self-center">
						<p class="my-0"><span data-bind="text: GiornoDellaSettimana, css: {'text-info': Festivo}, attr:{title: Festivo ? Festivita : ''}" title="">Venerdì</span></p>
					</div>
					<div class="col-8">
						<div class="row">
							<!-- ko foreach: Eventi -->
							<div class="col-2 align-self-center">
								<div class="calendar-box" data-bind="style: {'background-color': Colore ? '#' + Colore : '#BBBBBB' }, attr: {title: Testo}" title="Plastica" style="background-color: rgb(253, 255, 3);"><p class="my-0">&nbsp;</p></div>
							</div>
							<div class="col-4 align-self-center">
								<p class="my-0"><strong data-bind="text: Testo">Plastica</strong></p>
							</div>
							
							<div class="col-2 align-self-center">
								<div class="calendar-box" data-bind="style: {'background-color': Colore ? '#' + Colore : '#BBBBBB' }, attr: {title: Testo}" title="Umido" style="background-color: rgb(148, 73, 6);"><p class="my-0">&nbsp;</p></div>
							</div>
							<div class="col-4 align-self-center">
								<p class="my-0"><strong data-bind="text: Testo">Umido</strong></p>
							</div>
							<!-- /ko -->
						</div>
					</div>
				</div>
				
				<div class="row row-calendar" data-bind="css: {'row-today' : moment().format('DD/MMM/YYYY') == moment(Data).format('DD/MMM/YYYY') }, attr: {id: 'scroll-today'}" id="scroll-today">
					<div class="col-1 align-self-center text-center">
						<p class="my-0"><span data-bind="text: Data ? moment(Data).format('D') : '', css: {'text-info': Festivo}">6</span></p>
					</div>
					<div class="col-3 align-self-center">
						<p class="my-0"><span data-bind="text: GiornoDellaSettimana, css: {'text-info': Festivo}, attr:{title: Festivo ? Festivita : ''}" title="">Sabato</span></p>
					</div>
					<div class="col-8">
						<div class="row">
							<!-- ko foreach: Eventi -->
							<div class="col-2 align-self-center">
								<div class="calendar-box" data-bind="style: {'background-color': Colore ? '#' + Colore : '#BBBBBB' }, attr: {title: Testo}" title="Carta" style="background-color: rgb(0, 113, 194);"><p class="my-0">&nbsp;</p></div>
							</div>
							<div class="col-4 align-self-center">
								<p class="my-0"><strong data-bind="text: Testo">Carta</strong></p>
							</div>
							<!-- /ko -->
						</div>
					</div>
				</div>
				
				<div class="row row-calendar" data-bind="css: {'row-today' : moment().format('DD/MMM/YYYY') == moment(Data).format('DD/MMM/YYYY') }, attr: {id: 'scroll-today'}" id="scroll-today">
					<div class="col-1 align-self-center text-center">
						<p class="my-0"><span data-bind="text: Data ? moment(Data).format('D') : '', css: {'text-info': Festivo}" class="text-info">7</span></p>
					</div>
					<div class="col-3 align-self-center">
						<p class="my-0"><span data-bind="text: GiornoDellaSettimana, css: {'text-info': Festivo}, attr:{title: Festivo ? Festivita : ''}" class="text-info">Domenica</span></p>
					</div>
					<div class="col-8">
						<div class="row">
							<!-- ko foreach: Eventi --><!-- /ko -->
						</div>
					</div>
				</div>
				
				<div class="row row-calendar" data-bind="css: {'row-today' : moment().format('DD/MMM/YYYY') == moment(Data).format('DD/MMM/YYYY') }, attr: {id: 'scroll-today'}" id="scroll-today">
					<div class="col-1 align-self-center text-center">
						<p class="my-0"><span data-bind="text: Data ? moment(Data).format('D') : '', css: {'text-info': Festivo}">8</span></p>
					</div>
					<div class="col-3 align-self-center">
						<p class="my-0"><span data-bind="text: GiornoDellaSettimana, css: {'text-info': Festivo}, attr:{title: Festivo ? Festivita : ''}" title="">Lunedì</span></p>
					</div>
					<div class="col-8">
						<div class="row">
							<!-- ko foreach: Eventi --><!-- /ko -->
						</div>
					</div>
				</div>
				
				<div class="row row-calendar" data-bind="css: {'row-today' : moment().format('DD/MMM/YYYY') == moment(Data).format('DD/MMM/YYYY') }, attr: {id: 'scroll-today'}" id="scroll-today">
					<div class="col-1 align-self-center text-center">
						<p class="my-0"><span data-bind="text: Data ? moment(Data).format('D') : '', css: {'text-info': Festivo}">9</span></p>
					</div>
					<div class="col-3 align-self-center">
						<p class="my-0"><span data-bind="text: GiornoDellaSettimana, css: {'text-info': Festivo}, attr:{title: Festivo ? Festivita : ''}" title="">Martedì</span></p>
					</div>
					<div class="col-8">
						<div class="row">
							<!-- ko foreach: Eventi -->
							<div class="col-2 align-self-center">
								<div class="calendar-box" data-bind="style: {'background-color': Colore ? '#' + Colore : '#BBBBBB' }, attr: {title: Testo}" title="Umido" style="background-color: rgb(148, 73, 6);"><p class="my-0">&nbsp;</p></div>
							</div>
							<div class="col-4 align-self-center">
								<p class="my-0"><strong data-bind="text: Testo">Umido</strong></p>
							</div>
							
							<div class="col-2 align-self-center">
								<div class="calendar-box" data-bind="style: {'background-color': Colore ? '#' + Colore : '#BBBBBB' }, attr: {title: Testo}" title="Vetro" style="background-color: rgb(1, 103, 1);"><p class="my-0">&nbsp;</p></div>
							</div>
							<div class="col-4 align-self-center">
								<p class="my-0"><strong data-bind="text: Testo">Vetro</strong></p>
							</div>
							<!-- /ko -->
						</div>
					</div>
				</div>
				
				<div class="row row-calendar" data-bind="css: {'row-today' : moment().format('DD/MMM/YYYY') == moment(Data).format('DD/MMM/YYYY') }, attr: {id: 'scroll-today'}" id="scroll-today">
					<div class="col-1 align-self-center text-center">
						<p class="my-0"><span data-bind="text: Data ? moment(Data).format('D') : '', css: {'text-info': Festivo}">10</span></p>
					</div>
					<div class="col-3 align-self-center">
						<p class="my-0"><span data-bind="text: GiornoDellaSettimana, css: {'text-info': Festivo}, attr:{title: Festivo ? Festivita : ''}" title="">Mercoledì</span></p>
					</div>
					<div class="col-8">
						<div class="row">
							<!-- ko foreach: Eventi --><!-- /ko -->
						</div>
					</div>
				</div>
				
				<div class="row row-calendar" data-bind="css: {'row-today' : moment().format('DD/MMM/YYYY') == moment(Data).format('DD/MMM/YYYY') }, attr: {id: 'scroll-today'}" id="scroll-today">
					<div class="col-1 align-self-center text-center">
						<p class="my-0"><span data-bind="text: Data ? moment(Data).format('D') : '', css: {'text-info': Festivo}">11</span></p>
					</div>
					<div class="col-3 align-self-center">
						<p class="my-0"><span data-bind="text: GiornoDellaSettimana, css: {'text-info': Festivo}, attr:{title: Festivo ? Festivita : ''}" title="">Giovedì</span></p>
					</div>
					<div class="col-8">
						<div class="row">
							<!-- ko foreach: Eventi --><!-- /ko -->
						</div>
					</div>
				</div>
				
				<div class="row row-calendar" data-bind="css: {'row-today' : moment().format('DD/MMM/YYYY') == moment(Data).format('DD/MMM/YYYY') }, attr: {id: 'scroll-today'}" id="scroll-today">
					<div class="col-1 align-self-center text-center">
						<p class="my-0"><span data-bind="text: Data ? moment(Data).format('D') : '', css: {'text-info': Festivo}">12</span></p>
					</div>
					<div class="col-3 align-self-center">
						<p class="my-0"><span data-bind="text: GiornoDellaSettimana, css: {'text-info': Festivo}, attr:{title: Festivo ? Festivita : ''}" title="">Venerdì</span></p>
					</div>
					<div class="col-8">
						<div class="row">
							<!-- ko foreach: Eventi -->
							<div class="col-2 align-self-center">
								<div class="calendar-box" data-bind="style: {'background-color': Colore ? '#' + Colore : '#BBBBBB' }, attr: {title: Testo}" title="Plastica" style="background-color: rgb(253, 255, 3);"><p class="my-0">&nbsp;</p></div>
							</div>
							<div class="col-4 align-self-center">
								<p class="my-0"><strong data-bind="text: Testo">Plastica</strong></p>
							</div>
							
							<div class="col-2 align-self-center">
								<div class="calendar-box" data-bind="style: {'background-color': Colore ? '#' + Colore : '#BBBBBB' }, attr: {title: Testo}" title="Umido" style="background-color: rgb(148, 73, 6);"><p class="my-0">&nbsp;</p></div>
							</div>
							<div class="col-4 align-self-center">
								<p class="my-0"><strong data-bind="text: Testo">Umido</strong></p>
							</div>
							<!-- /ko -->
						</div>
					</div>
				</div>
				
				<div class="row row-calendar" data-bind="css: {'row-today' : moment().format('DD/MMM/YYYY') == moment(Data).format('DD/MMM/YYYY') }, attr: {id: 'scroll-today'}" id="scroll-today">
					<div class="col-1 align-self-center text-center">
						<p class="my-0"><span data-bind="text: Data ? moment(Data).format('D') : '', css: {'text-info': Festivo}">13</span></p>
					</div>
					<div class="col-3 align-self-center">
						<p class="my-0"><span data-bind="text: GiornoDellaSettimana, css: {'text-info': Festivo}, attr:{title: Festivo ? Festivita : ''}" title="">Sabato</span></p>
					</div>
					<div class="col-8">
						<div class="row">
							<!-- ko foreach: Eventi -->
							<div class="col-2 align-self-center">
								<div class="calendar-box" data-bind="style: {'background-color': Colore ? '#' + Colore : '#BBBBBB' }, attr: {title: Testo}" title="Carta" style="background-color: rgb(0, 113, 194);"><p class="my-0">&nbsp;</p></div>
							</div>
							<div class="col-4 align-self-center">
								<p class="my-0"><strong data-bind="text: Testo">Carta</strong></p>
							</div>
							<!-- /ko -->
						</div>
					</div>
				</div>
				
				<div class="row row-calendar" data-bind="css: {'row-today' : moment().format('DD/MMM/YYYY') == moment(Data).format('DD/MMM/YYYY') }, attr: {id: 'scroll-today'}" id="scroll-today">
					<div class="col-1 align-self-center text-center">
						<p class="my-0"><span data-bind="text: Data ? moment(Data).format('D') : '', css: {'text-info': Festivo}" class="text-info">14</span></p>
					</div>
					<div class="col-3 align-self-center">
						<p class="my-0"><span data-bind="text: GiornoDellaSettimana, css: {'text-info': Festivo}, attr:{title: Festivo ? Festivita : ''}" class="text-info">Domenica</span></p>
					</div>
					<div class="col-8">
						<div class="row">
							<!-- ko foreach: Eventi --><!-- /ko -->
						</div>
					</div>
				</div>
				
				<div class="row row-calendar" data-bind="css: {'row-today' : moment().format('DD/MMM/YYYY') == moment(Data).format('DD/MMM/YYYY') }, attr: {id: 'scroll-today'}" id="scroll-today">
					<div class="col-1 align-self-center text-center">
						<p class="my-0"><span data-bind="text: Data ? moment(Data).format('D') : '', css: {'text-info': Festivo}">15</span></p>
					</div>
					<div class="col-3 align-self-center">
						<p class="my-0"><span data-bind="text: GiornoDellaSettimana, css: {'text-info': Festivo}, attr:{title: Festivo ? Festivita : ''}" title="">Lunedì</span></p>
					</div>
					<div class="col-8">
						<div class="row">
							<!-- ko foreach: Eventi --><!-- /ko -->
						</div>
					</div>
				</div>
				
				<div class="row row-calendar" data-bind="css: {'row-today' : moment().format('DD/MMM/YYYY') == moment(Data).format('DD/MMM/YYYY') }, attr: {id: 'scroll-today'}" id="scroll-today">
					<div class="col-1 align-self-center text-center">
						<p class="my-0"><span data-bind="text: Data ? moment(Data).format('D') : '', css: {'text-info': Festivo}">16</span></p>
					</div>
					<div class="col-3 align-self-center">
						<p class="my-0"><span data-bind="text: GiornoDellaSettimana, css: {'text-info': Festivo}, attr:{title: Festivo ? Festivita : ''}" title="">Martedì</span></p>
					</div>
					<div class="col-8">
						<div class="row">
							<!-- ko foreach: Eventi -->
							<div class="col-2 align-self-center">
								<div class="calendar-box" data-bind="style: {'background-color': Colore ? '#' + Colore : '#BBBBBB' }, attr: {title: Testo}" title="Secco" style="background-color: rgb(131, 126, 133);"><p class="my-0">&nbsp;</p></div>
							</div>
							<div class="col-4 align-self-center">
								<p class="my-0"><strong data-bind="text: Testo">Secco</strong></p>
							</div>
							
							<div class="col-2 align-self-center">
								<div class="calendar-box" data-bind="style: {'background-color': Colore ? '#' + Colore : '#BBBBBB' }, attr: {title: Testo}" title="Umido" style="background-color: rgb(148, 73, 6);"><p class="my-0">&nbsp;</p></div>
							</div>
							<div class="col-4 align-self-center">
								<p class="my-0"><strong data-bind="text: Testo">Umido</strong></p>
							</div>
							<!-- /ko -->
						</div>
					</div>
				</div>
				
				<div class="row row-calendar" data-bind="css: {'row-today' : moment().format('DD/MMM/YYYY') == moment(Data).format('DD/MMM/YYYY') }, attr: {id: 'scroll-today'}" id="scroll-today">
					<div class="col-1 align-self-center text-center">
						<p class="my-0"><span data-bind="text: Data ? moment(Data).format('D') : '', css: {'text-info': Festivo}">17</span></p>
					</div>
					<div class="col-3 align-self-center">
						<p class="my-0"><span data-bind="text: GiornoDellaSettimana, css: {'text-info': Festivo}, attr:{title: Festivo ? Festivita : ''}" title="">Mercoledì</span></p>
					</div>
					<div class="col-8">
						<div class="row">
							<!-- ko foreach: Eventi --><!-- /ko -->
						</div>
					</div>
				</div>
				
				<div class="row row-calendar" data-bind="css: {'row-today' : moment().format('DD/MMM/YYYY') == moment(Data).format('DD/MMM/YYYY') }, attr: {id: 'scroll-today'}" id="scroll-today">
					<div class="col-1 align-self-center text-center">
						<p class="my-0"><span data-bind="text: Data ? moment(Data).format('D') : '', css: {'text-info': Festivo}">18</span></p>
					</div>
					<div class="col-3 align-self-center">
						<p class="my-0"><span data-bind="text: GiornoDellaSettimana, css: {'text-info': Festivo}, attr:{title: Festivo ? Festivita : ''}" title="">Giovedì</span></p>
					</div>
					<div class="col-8">
						<div class="row">
							<!-- ko foreach: Eventi --><!-- /ko -->
						</div>
					</div>
				</div>
				
				<div class="row row-calendar" data-bind="css: {'row-today' : moment().format('DD/MMM/YYYY') == moment(Data).format('DD/MMM/YYYY') }, attr: {id: 'scroll-today'}" id="scroll-today">
					<div class="col-1 align-self-center text-center">
						<p class="my-0"><span data-bind="text: Data ? moment(Data).format('D') : '', css: {'text-info': Festivo}">19</span></p>
					</div>
					<div class="col-3 align-self-center">
						<p class="my-0"><span data-bind="text: GiornoDellaSettimana, css: {'text-info': Festivo}, attr:{title: Festivo ? Festivita : ''}" title="">Venerdì</span></p>
					</div>
					<div class="col-8">
						<div class="row">
							<!-- ko foreach: Eventi -->
							<div class="col-2 align-self-center">
								<div class="calendar-box" data-bind="style: {'background-color': Colore ? '#' + Colore : '#BBBBBB' }, attr: {title: Testo}" title="Plastica" style="background-color: rgb(253, 255, 3);"><p class="my-0">&nbsp;</p></div>
							</div>
							<div class="col-4 align-self-center">
								<p class="my-0"><strong data-bind="text: Testo">Plastica</strong></p>
							</div>
							
							<div class="col-2 align-self-center">
								<div class="calendar-box" data-bind="style: {'background-color': Colore ? '#' + Colore : '#BBBBBB' }, attr: {title: Testo}" title="Umido" style="background-color: rgb(148, 73, 6);"><p class="my-0">&nbsp;</p></div>
							</div>
							<div class="col-4 align-self-center">
								<p class="my-0"><strong data-bind="text: Testo">Umido</strong></p>
							</div>
							<!-- /ko -->
						</div>
					</div>
				</div>
				
				<div class="row row-calendar" data-bind="css: {'row-today' : moment().format('DD/MMM/YYYY') == moment(Data).format('DD/MMM/YYYY') }, attr: {id: 'scroll-today'}" id="scroll-today">
					<div class="col-1 align-self-center text-center">
						<p class="my-0"><span data-bind="text: Data ? moment(Data).format('D') : '', css: {'text-info': Festivo}">20</span></p>
					</div>
					<div class="col-3 align-self-center">
						<p class="my-0"><span data-bind="text: GiornoDellaSettimana, css: {'text-info': Festivo}, attr:{title: Festivo ? Festivita : ''}" title="">Sabato</span></p>
					</div>
					<div class="col-8">
						<div class="row">
							<!-- ko foreach: Eventi -->
							<div class="col-2 align-self-center">
								<div class="calendar-box" data-bind="style: {'background-color': Colore ? '#' + Colore : '#BBBBBB' }, attr: {title: Testo}" title="Carta" style="background-color: rgb(0, 113, 194);"><p class="my-0">&nbsp;</p></div>
							</div>
							<div class="col-4 align-self-center">
								<p class="my-0"><strong data-bind="text: Testo">Carta</strong></p>
							</div>
							<!-- /ko -->
						</div>
					</div>
				</div>
				
				<div class="row row-calendar" data-bind="css: {'row-today' : moment().format('DD/MMM/YYYY') == moment(Data).format('DD/MMM/YYYY') }, attr: {id: 'scroll-today'}" id="scroll-today">
					<div class="col-1 align-self-center text-center">
						<p class="my-0"><span data-bind="text: Data ? moment(Data).format('D') : '', css: {'text-info': Festivo}" class="text-info">21</span></p>
					</div>
					<div class="col-3 align-self-center">
						<p class="my-0"><span data-bind="text: GiornoDellaSettimana, css: {'text-info': Festivo}, attr:{title: Festivo ? Festivita : ''}" class="text-info">Domenica</span></p>
					</div>
					<div class="col-8">
						<div class="row">
							<!-- ko foreach: Eventi --><!-- /ko -->
						</div>
					</div>
				</div>
				
				<div class="row row-calendar" data-bind="css: {'row-today' : moment().format('DD/MMM/YYYY') == moment(Data).format('DD/MMM/YYYY') }, attr: {id: 'scroll-today'}" id="scroll-today">
					<div class="col-1 align-self-center text-center">
						<p class="my-0"><span data-bind="text: Data ? moment(Data).format('D') : '', css: {'text-info': Festivo}">22</span></p>
					</div>
					<div class="col-3 align-self-center">
						<p class="my-0"><span data-bind="text: GiornoDellaSettimana, css: {'text-info': Festivo}, attr:{title: Festivo ? Festivita : ''}" title="">Lunedì</span></p>
					</div>
					<div class="col-8">
						<div class="row">
							<!-- ko foreach: Eventi --><!-- /ko -->
						</div>
					</div>
				</div>
				
				<div class="row row-calendar" data-bind="css: {'row-today' : moment().format('DD/MMM/YYYY') == moment(Data).format('DD/MMM/YYYY') }, attr: {id: 'scroll-today'}" id="scroll-today">
					<div class="col-1 align-self-center text-center">
						<p class="my-0"><span data-bind="text: Data ? moment(Data).format('D') : '', css: {'text-info': Festivo}">23</span></p>
					</div>
					<div class="col-3 align-self-center">
						<p class="my-0"><span data-bind="text: GiornoDellaSettimana, css: {'text-info': Festivo}, attr:{title: Festivo ? Festivita : ''}" title="">Martedì</span></p>
					</div>
					<div class="col-8">
						<div class="row">
							<!-- ko foreach: Eventi -->
							<div class="col-2 align-self-center">
								<div class="calendar-box" data-bind="style: {'background-color': Colore ? '#' + Colore : '#BBBBBB' }, attr: {title: Testo}" title="Umido" style="background-color: rgb(148, 73, 6);"><p class="my-0">&nbsp;</p></div>
							</div>
							<div class="col-4 align-self-center">
								<p class="my-0"><strong data-bind="text: Testo">Umido</strong></p>
							</div>
							
							<div class="col-2 align-self-center">
								<div class="calendar-box" data-bind="style: {'background-color': Colore ? '#' + Colore : '#BBBBBB' }, attr: {title: Testo}" title="Vetro" style="background-color: rgb(1, 103, 1);"><p class="my-0">&nbsp;</p></div>
							</div>
							<div class="col-4 align-self-center">
								<p class="my-0"><strong data-bind="text: Testo">Vetro</strong></p>
							</div>
							<!-- /ko -->
						</div>
					</div>
				</div>
				
				<div class="row row-calendar" data-bind="css: {'row-today' : moment().format('DD/MMM/YYYY') == moment(Data).format('DD/MMM/YYYY') }, attr: {id: 'scroll-today'}" id="scroll-today">
					<div class="col-1 align-self-center text-center">
						<p class="my-0"><span data-bind="text: Data ? moment(Data).format('D') : '', css: {'text-info': Festivo}">24</span></p>
					</div>
					<div class="col-3 align-self-center">
						<p class="my-0"><span data-bind="text: GiornoDellaSettimana, css: {'text-info': Festivo}, attr:{title: Festivo ? Festivita : ''}" title="">Mercoledì</span></p>
					</div>
					<div class="col-8">
						<div class="row">
							<!-- ko foreach: Eventi --><!-- /ko -->
						</div>
					</div>
				</div>
				
				<div class="row row-calendar" data-bind="css: {'row-today' : moment().format('DD/MMM/YYYY') == moment(Data).format('DD/MMM/YYYY') }, attr: {id: 'scroll-today'}" id="scroll-today">
					<div class="col-1 align-self-center text-center">
						<p class="my-0"><span data-bind="text: Data ? moment(Data).format('D') : '', css: {'text-info': Festivo}">25</span></p>
					</div>
					<div class="col-3 align-self-center">
						<p class="my-0"><span data-bind="text: GiornoDellaSettimana, css: {'text-info': Festivo}, attr:{title: Festivo ? Festivita : ''}" title="">Giovedì</span></p>
					</div>
					<div class="col-8">
						<div class="row">
							<!-- ko foreach: Eventi --><!-- /ko -->
						</div>
					</div>
				</div>
				
				<div class="row row-calendar" data-bind="css: {'row-today' : moment().format('DD/MMM/YYYY') == moment(Data).format('DD/MMM/YYYY') }, attr: {id: 'scroll-today'}" id="scroll-today">
					<div class="col-1 align-self-center text-center">
						<p class="my-0"><span data-bind="text: Data ? moment(Data).format('D') : '', css: {'text-info': Festivo}">26</span></p>
					</div>
					<div class="col-3 align-self-center">
						<p class="my-0"><span data-bind="text: GiornoDellaSettimana, css: {'text-info': Festivo}, attr:{title: Festivo ? Festivita : ''}" title="">Venerdì</span></p>
					</div>
					<div class="col-8">
						<div class="row">
							<!-- ko foreach: Eventi -->
							<div class="col-2 align-self-center">
								<div class="calendar-box" data-bind="style: {'background-color': Colore ? '#' + Colore : '#BBBBBB' }, attr: {title: Testo}" title="Plastica" style="background-color: rgb(253, 255, 3);"><p class="my-0">&nbsp;</p></div>
							</div>
							<div class="col-4 align-self-center">
								<p class="my-0"><strong data-bind="text: Testo">Plastica</strong></p>
							</div>
							
							<div class="col-2 align-self-center">
								<div class="calendar-box" data-bind="style: {'background-color': Colore ? '#' + Colore : '#BBBBBB' }, attr: {title: Testo}" title="Umido" style="background-color: rgb(148, 73, 6);"><p class="my-0">&nbsp;</p></div>
							</div>
							<div class="col-4 align-self-center">
								<p class="my-0"><strong data-bind="text: Testo">Umido</strong></p>
							</div>
							<!-- /ko -->
						</div>
					</div>
				</div>
				
				<div class="row row-calendar" data-bind="css: {'row-today' : moment().format('DD/MMM/YYYY') == moment(Data).format('DD/MMM/YYYY') }, attr: {id: 'scroll-today'}" id="scroll-today">
					<div class="col-1 align-self-center text-center">
						<p class="my-0"><span data-bind="text: Data ? moment(Data).format('D') : '', css: {'text-info': Festivo}">27</span></p>
					</div>
					<div class="col-3 align-self-center">
						<p class="my-0"><span data-bind="text: GiornoDellaSettimana, css: {'text-info': Festivo}, attr:{title: Festivo ? Festivita : ''}" title="">Sabato</span></p>
					</div>
					<div class="col-8">
						<div class="row">
							<!-- ko foreach: Eventi -->
							<div class="col-2 align-self-center">
								<div class="calendar-box" data-bind="style: {'background-color': Colore ? '#' + Colore : '#BBBBBB' }, attr: {title: Testo}" title="Carta" style="background-color: rgb(0, 113, 194);"><p class="my-0">&nbsp;</p></div>
							</div>
							<div class="col-4 align-self-center">
								<p class="my-0"><strong data-bind="text: Testo">Carta</strong></p>
							</div>
							<!-- /ko -->
						</div>
					</div>
				</div>
				
				<div class="row row-calendar" data-bind="css: {'row-today' : moment().format('DD/MMM/YYYY') == moment(Data).format('DD/MMM/YYYY') }, attr: {id: 'scroll-today'}" id="scroll-today">
					<div class="col-1 align-self-center text-center">
						<p class="my-0"><span data-bind="text: Data ? moment(Data).format('D') : '', css: {'text-info': Festivo}" class="text-info">28</span></p>
					</div>
					<div class="col-3 align-self-center">
						<p class="my-0"><span data-bind="text: GiornoDellaSettimana, css: {'text-info': Festivo}, attr:{title: Festivo ? Festivita : ''}" class="text-info">Domenica</span></p>
					</div>
					<div class="col-8">
						<div class="row">
							<!-- ko foreach: Eventi --><!-- /ko -->
						</div>
					</div>
				</div>
				
				<div class="row row-calendar" data-bind="css: {'row-today' : moment().format('DD/MMM/YYYY') == moment(Data).format('DD/MMM/YYYY') }, attr: {id: 'scroll-today'}" id="scroll-today">
					<div class="col-1 align-self-center text-center">
						<p class="my-0"><span data-bind="text: Data ? moment(Data).format('D') : '', css: {'text-info': Festivo}">29</span></p>
					</div>
					<div class="col-3 align-self-center">
						<p class="my-0"><span data-bind="text: GiornoDellaSettimana, css: {'text-info': Festivo}, attr:{title: Festivo ? Festivita : ''}" title="">Lunedì</span></p>
					</div>
					<div class="col-8">
						<div class="row">
							<!-- ko foreach: Eventi --><!-- /ko -->
						</div>
					</div>
				</div>
				
				<div class="row row-calendar" data-bind="css: {'row-today' : moment().format('DD/MMM/YYYY') == moment(Data).format('DD/MMM/YYYY') }, attr: {id: 'scroll-today'}" id="scroll-today">
					<div class="col-1 align-self-center text-center">
						<p class="my-0"><span data-bind="text: Data ? moment(Data).format('D') : '', css: {'text-info': Festivo}">30</span></p>
					</div>
					<div class="col-3 align-self-center">
						<p class="my-0"><span data-bind="text: GiornoDellaSettimana, css: {'text-info': Festivo}, attr:{title: Festivo ? Festivita : ''}" title="">Martedì</span></p>
					</div>
					<div class="col-8">
						<div class="row">
							<!-- ko foreach: Eventi -->
							<div class="col-2 align-self-center">
								<div class="calendar-box" data-bind="style: {'background-color': Colore ? '#' + Colore : '#BBBBBB' }, attr: {title: Testo}" title="Secco" style="background-color: rgb(131, 126, 133);"><p class="my-0">&nbsp;</p></div>
							</div>
							<div class="col-4 align-self-center">
								<p class="my-0"><strong data-bind="text: Testo">Secco</strong></p>
							</div>
							
							<div class="col-2 align-self-center">
								<div class="calendar-box" data-bind="style: {'background-color': Colore ? '#' + Colore : '#BBBBBB' }, attr: {title: Testo}" title="Umido" style="background-color: rgb(148, 73, 6);"><p class="my-0">&nbsp;</p></div>
							</div>
							<div class="col-4 align-self-center">
								<p class="my-0"><strong data-bind="text: Testo">Umido</strong></p>
							</div>
							<!-- /ko -->
						</div>
					</div>
				</div>
				
				<div class="row row-calendar" data-bind="css: {'row-today' : moment().format('DD/MMM/YYYY') == moment(Data).format('DD/MMM/YYYY') }, attr: {id: 'scroll-today'}" id="scroll-today">
					<div class="col-1 align-self-center text-center">
						<p class="my-0"><span data-bind="text: Data ? moment(Data).format('D') : '', css: {'text-info': Festivo}">31</span></p>
					</div>
					<div class="col-3 align-self-center">
						<p class="my-0"><span data-bind="text: GiornoDellaSettimana, css: {'text-info': Festivo}, attr:{title: Festivo ? Festivita : ''}" title="">Mercoledì</span></p>
					</div>
					<div class="col-8">
						<div class="row">
							<!-- ko foreach: Eventi --><!-- /ko -->
						</div>
					</div>
				</div>
				<!-- /ko -->
			</div>"""

# %%
from IPython.display import HTML

HTML(calendar_may)
# Out:
# 				<!-- ko foreach: Mese().Giorni-->
# 				<div class="row row-calendar" data-bind="css: {'row-today' : moment().format('DD/MMM/YYYY') == moment(Data).format('DD/MMM/YYYY') }, attr: {id: 'scroll-today'}" id="scroll-today">
# 					<div class="col-1 align-self-center text-center">
# 						<p class="my-0"><span data-bind="text: Data ? moment(Data).format('D') : '', css: {'text-info': Festivo}" class="text-info">1</span></p>
# 					</div>
# 					<div class="col-3 align-self-center">
# 						<p class="my-0"><span data-bind="text: GiornoDellaSettimana, css: {'text-info': Festivo}, attr:{title: Festivo ? Festivita : ''}" class="text-info" title="Festa del lavoro">Lunedì</span></p>
# 					</div>
# 					<div class="col-8">
# 						<div class="row">
# 							<!-- ko foreach: Eventi --><!-- /ko -->
# 						</div>
# 					</div>
# 				</div>
#
# ...

# %%
# !pip install bs4

# %%
from bs4 import BeautifulSoup
soup = BeautifulSoup(calendar_may, 'html.parser') # data is your table from question
days = []
rifiuti= []
for day in soup.find_all("p", class_="my-0"):    
    if(day.get_text(strip=True)):
        days.append(day.get_text(strip=True))
print(days)
# Out:
# ['1', 'Lunedì', '2', 'Martedì', 'Secco', 'Umido', '3', 'Mercoledì', '4', 'Giovedì', '5', 'Venerdì', 'Plastica', 'Umido', '6', 'Sabato', 'Carta', '7', 'Domenica', '8', 'Lunedì', '9', 'Martedì', 'Umido', 'Vetro', '10', 'Mercoledì', '11', 'Giovedì', '12', 'Venerdì', 'Plastica', 'Umido', '13', 'Sabato', 'Carta', '14', 'Domenica', '15', 'Lunedì', '16', 'Martedì', 'Secco', 'Umido', '17', 'Mercoledì', '18', 'Giovedì', '19', 'Venerdì', 'Plastica', 'Umido', '20', 'Sabato', 'Carta', '21', 'Domenica', '22', 'Lunedì', '23', 'Martedì', 'Umido', 'Vetro', '24', 'Mercoledì', '25', 'Giovedì', '26', 'Venerdì', 'Plastica', 'Umido', '27', 'Sabato', 'Carta', '28', 'Domenica', '29', 'Lunedì', '30', 'Martedì', 'Secco', 'Umido', '31', 'Mercoledì']

# %%
prompt = f"""
Your task is to select the 
<day>: day of the month
<week_name>:  day of the week 
<rifiuti>: all the text that follows separated by commas.

<today>: 6
Write these elements for day <today> provided in the calendar given delimited by  triple backticks.
Calendar: ```{days}```
"""
response = get_completion(prompt)
print(response)
# Out:
# <day>: 6
# <week_name>: Sabato
# <rifiuti>: Carta
